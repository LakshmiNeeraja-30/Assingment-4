# %%
import pandas as pd
a=pd.read_csv("1000records.csv")
a
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     31        No  Travel_Frequently        836                 Support
# 1     43       Yes         Non-Travel       1071         Human Resources
# 2     25       Yes         Non-Travel       1374  Research & Development
# 3     29        No  Travel_Frequently       1415                 Support
# 4     20       Yes      Travel_Rarely       1076         Human Resources
# ..   ...       ...                ...        ...                     ...
# 995   49        No         Non-Travel       1465                 Support
# 996   24       Yes  Travel_Frequently        387                   Sales
# 997   45       Yes      Travel_Rarely       1304                Software
# 998   39        No         Non-Travel        217                Hardware
# 999   19       Yes  Travel_Frequently       1447                Hardware
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
b=a[(a.Age>20)&(a.Education>3)]
b
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     31        No  Travel_Frequently        836                 Support
# 2     25       Yes         Non-Travel       1374  Research & Development
# 8     41        No         Non-Travel       1074                   Sales
# 15    41        No         Non-Travel        753                   Sales
# 17    27        No  Travel_Frequently        804  Research & Development
# ..   ...       ...                ...        ...                     ...
# 986   33       Yes      Travel_Rarely        799         Human Resources
# 987   24       Yes         Non-Travel        440                   Sales
# 990   32       Yes  Travel_Frequently        981                   Sales
# 997   45       Yes      Travel_Rarely       1304                Software
# 998   39        No         Non-Travel        217                Hardware
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
a.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   31        No  Travel_Frequently        836                 Support
# 1   43       Yes         Non-Travel       1071         Human Resources
# 2   25       Yes         Non-Travel       1374  Research & Development
# 3   29        No  Travel_Frequently       1415                 Support
# 4   20       Yes      Travel_Rarely       1076         Human Resources
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                16          5             Other              1
# 1                14          3             Other              1
# 2                 3          5     Life Sciences              1
# 3                30          2  Technical Degree              1
# 4                19          3           Medical              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0               1  ...                         3            80
# ...

# %%
a.tail()
# Out:
#      Age Attrition     BusinessTravel  DailyRate Department  DistanceFromHome  \
# 995   49        No         Non-Travel       1465    Support                28
# 996   24       Yes  Travel_Frequently        387      Sales                45
# 997   45       Yes      Travel_Rarely       1304   Software                 7
# 998   39        No         Non-Travel        217   Hardware                39
# 999   19       Yes  Travel_Frequently       1447   Hardware                 6
#
#      Education    EducationField  EmployeeCount  EmployeeNumber  ...  \
# 995          3   Human Resources              1             996  ...
# 996          3  Technical Degree              1             997  ...
# 997          5             Other              1             998  ...
# 998          4   Human Resources              1             999  ...
# 999          5     Life Sciences              1            1000  ...
#
#      RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
a.head(100)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    31        No  Travel_Frequently        836                 Support
# 1    43       Yes         Non-Travel       1071         Human Resources
# 2    25       Yes         Non-Travel       1374  Research & Development
# 3    29        No  Travel_Frequently       1415                 Support
# 4    20       Yes      Travel_Rarely       1076         Human Resources
# ..  ...       ...                ...        ...                     ...
# 95   45       Yes         Non-Travel        577                Software
# 96   59        No  Travel_Frequently        282                Hardware
# 97   25       Yes         Non-Travel        542                 Support
# 98   25       Yes  Travel_Frequently        918  Research & Development
# 99   35       Yes         Non-Travel        459                Software
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
c=a.head(30)
c
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    31        No  Travel_Frequently        836                 Support
# 1    43       Yes         Non-Travel       1071         Human Resources
# 2    25       Yes         Non-Travel       1374  Research & Development
# 3    29        No  Travel_Frequently       1415                 Support
# 4    20       Yes      Travel_Rarely       1076         Human Resources
# 5    46       Yes  Travel_Frequently       1176         Human Resources
# 6    52        No         Non-Travel       1311                 Support
# 7    18        No      Travel_Rarely        319         Human Resources
# 8    41        No         Non-Travel       1074                   Sales
# 9    44        No      Travel_Rarely        119                Hardware
# 10   34        No         Non-Travel        775                 Support
# 11   55       Yes  Travel_Frequently       1233                 Support
# ...

# %%
d=c.tail(10)
d
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 20   32       Yes      Travel_Rarely        934  Research & Development
# 21   33        No  Travel_Frequently        811                 Support
# 22   46       Yes         Non-Travel       1100                Software
# 23   43        No         Non-Travel        915                 Support
# 24   19        No         Non-Travel        561                   Sales
# 25   19       Yes      Travel_Rarely       1219                   Sales
# 26   37        No      Travel_Rarely       1224                 Support
# 27   35        No  Travel_Frequently       1266                Software
# 28   53        No  Travel_Frequently       1373                   Sales
# 29   58        No  Travel_Frequently        519  Research & Development
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# 20                43          3             Other              1
# ...

# %%
a["Age"]
# Out:
# 0      31
# 1      43
# 2      25
# 3      29
# 4      20
#        ..
# 995    49
# 996    24
# 997    45
# 998    39
# 999    19
# Name: Age, Length: 1000, dtype: int64

# %%
a["marks"]=11
a
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     31        No  Travel_Frequently        836                 Support
# 1     43       Yes         Non-Travel       1071         Human Resources
# 2     25       Yes         Non-Travel       1374  Research & Development
# 3     29        No  Travel_Frequently       1415                 Support
# 4     20       Yes      Travel_Rarely       1076         Human Resources
# ..   ...       ...                ...        ...                     ...
# 995   49        No         Non-Travel       1465                 Support
# 996   24       Yes  Travel_Frequently        387                   Sales
# 997   45       Yes      Travel_Rarely       1304                Software
# 998   39        No         Non-Travel        217                Hardware
# 999   19       Yes  Travel_Frequently       1447                Hardware
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
print(a.loc[10])
# Out:
# Age                                        34
# Attrition                                  No
# BusinessTravel                     Non-Travel
# DailyRate                                 775
# Department                            Support
# DistanceFromHome                           31
# Education                                   3
# EducationField                      Marketing
# EmployeeCount                               1
# EmployeeNumber                             11
# EnvironmentSatisfaction                     2
# Gender                                 Female
# HourlyRate                                112
# JobInvolvement                              2
# JobLevel                                    1
# JobRole                     Research Director
# JobSatisfaction                             3
# MaritalStatus                          Single
# MonthlyIncome                            7030
# MonthlyRate                             35150
# ...

# %%
a.info
# Out:
# <bound method DataFrame.info of      Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     31        No  Travel_Frequently        836                 Support
# 1     43       Yes         Non-Travel       1071         Human Resources
# 2     25       Yes         Non-Travel       1374  Research & Development
# 3     29        No  Travel_Frequently       1415                 Support
# 4     20       Yes      Travel_Rarely       1076         Human Resources
# ..   ...       ...                ...        ...                     ...
# 995   49        No         Non-Travel       1465                 Support
# 996   24       Yes  Travel_Frequently        387                   Sales
# 997   45       Yes      Travel_Rarely       1304                Software
# 998   39        No         Non-Travel        217                Hardware
# 999   19       Yes  Travel_Frequently       1447                Hardware
#
# ...

# %%
a.describe()
# Out:
#                Age    DailyRate  DistanceFromHome   Education  EmployeeCount  \
# count  1000.000000  1000.000000       1000.000000  1000.00000         1000.0
# mean     38.487000   835.616000         25.455000     3.04100            1.0
# std      12.610268   401.419232         14.762585     1.41468            0.0
# min      18.000000   100.000000          1.000000     1.00000            1.0
# 25%      28.000000   508.500000         13.000000     2.00000            1.0
# 50%      38.000000   863.500000         25.000000     3.00000            1.0
# 75%      50.000000  1176.000000         39.000000     4.00000            1.0
# max      60.000000  1499.000000         50.000000     5.00000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1000.000000              1000.000000  1000.000000     1000.000000
# mean       500.500000                 2.512000   112.537000        2.500000
# ...

# %%
a.min()
# Out:
# Age                                      18
# Attrition                                No
# BusinessTravel                   Non-Travel
# DailyRate                               100
# Department                         Hardware
# DistanceFromHome                          1
# Education                                 1
# EducationField              Human Resources
# EmployeeCount                             1
# EmployeeNumber                            1
# EnvironmentSatisfaction                   1
# Gender                               Female
# HourlyRate                               30
# JobInvolvement                            1
# JobLevel                                  1
# JobRole                           Developer
# JobSatisfaction                           1
# MaritalStatus                      Divorced
# MonthlyIncome                          1090
# MonthlyRate                            2289
# NumCompaniesWorked                        0
# ...

# %%
a.max()
# Out:
# Age                                           60
# Attrition                                    Yes
# BusinessTravel                     Travel_Rarely
# DailyRate                                   1499
# Department                               Support
# DistanceFromHome                              50
# Education                                      5
# EducationField                  Technical Degree
# EmployeeCount                                  1
# EmployeeNumber                              1000
# EnvironmentSatisfaction                        4
# Gender                                      Male
# HourlyRate                                   200
# JobInvolvement                                 4
# JobLevel                                       5
# JobRole                     Sales Representative
# JobSatisfaction                                4
# MaritalStatus                             Single
# MonthlyIncome                              50924
# ...

# %%
a["Age"]>8
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 995    True
# 996    True
# 997    True
# 998    True
# 999    True
# Name: Age, Length: 1000, dtype: bool

# %%
a[a["Age"]>8]
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     31        No  Travel_Frequently        836                 Support
# 1     43       Yes         Non-Travel       1071         Human Resources
# 2     25       Yes         Non-Travel       1374  Research & Development
# 3     29        No  Travel_Frequently       1415                 Support
# 4     20       Yes      Travel_Rarely       1076         Human Resources
# ..   ...       ...                ...        ...                     ...
# 995   49        No         Non-Travel       1465                 Support
# 996   24       Yes  Travel_Frequently        387                   Sales
# 997   45       Yes      Travel_Rarely       1304                Software
# 998   39        No         Non-Travel        217                Hardware
# 999   19       Yes  Travel_Frequently       1447                Hardware
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...
