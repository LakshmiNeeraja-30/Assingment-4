# %%
import pandas as pd
import numpy as np
a=pd.read_csv("data.csv")
a
# Out:
#     S.No      ID No                  Name of the Student    Class  \
# 0      1    S160884                          Reddi.Kumar  CSE -4F
# 1      2    S160849                   Peketi siva sankar  CSE -4F
# 2      3    S161000                       P.v.b.g.Sharma  CSE -4F
# 3      4    S160931                YATAM RAMESH THRINADH  CSE -4F
# 4      5    S160196                    Gadu Appala Naidu  CSE -4F
# 5      6    S160404             Netheti Siva Ram Krishna  CSE -4F
# 6      7    S160401         Bolisetty Naga Venkata Manoj  CSE -4F
# 7      8    S160296           Bakkamanthula Hari Krishna  CSE -4F
# 8      9    S160132                        V.S.N.V.Mohan  CSE -4F
# 9     10    S160273                             B.Prasad  CSE -4F
# 10    11    S160542                            K.Sathvik  CSE -4F
# 11    12    S160559                       D.jagannadhrao  CSE -4F
# 12    13    S161105                   Gandavarapu.Ramesh  CSE -4F
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 8 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   S.No                                   58 non-null     int64
#  1   ID No                                  58 non-null     object
#  2   Name of the Student                    58 non-null     object
#  3   Class                                  58 non-null     object
#  4   Mail Id                                58 non-null     object
#  5   Placed/Not (Yes/No)                    58 non-null     object
#  6   Company Names                          55 non-null     object
#  7   Any Reason (Higher Studies/GOVT Jobs)  5 non-null      object
# dtypes: int64(1), object(7)
# memory usage: 3.8+ KB

# %%
a.describe()
# Out:
#             S.No
# count  58.000000
# mean   29.500000
# std    16.886879
# min     1.000000
# 25%    15.250000
# 50%    29.500000
# 75%    43.750000
# max    58.000000

# %%
a["Name of the Student"
